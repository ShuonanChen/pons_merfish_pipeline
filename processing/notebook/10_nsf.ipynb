# %%
import sys

print(sys.version)
print(sys.executable)
# Out:
# 3.11.11 | packaged by conda-forge | (main, Mar  3 2025, 20:43:55) [GCC 13.3.0]
# /allen/aind/scratch/shuonan.chen/conda_envs/nsf/bin/python

# %%
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt

# %%
filename = '/allen/aind/scratch/shuonan.chen/code/pons_merfish_pipeline/processing/data/adata_mer_subset_2_6k.h5ad'
adata_mer = sc.read_h5ad(filename)

# %%
import spatial_factorization
# Out:
# 2025-06-23 15:38:37.561023: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 15:38:38.724972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750718319.107585 3721195 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750718319.227747 3721195 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
L = 4 #number of components
Z = misc.kmeans_inducing_pts(Xtr, 500)
M = Z.shape[0] #number of inducing points
ker = tfk.MaternThreeHalves
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 L = 4 #number of components
# ----> 2 Z = misc.kmeans_inducing_pts(Xtr, 500)
#       3 M = Z.shape[0] #number of inducing points
#       4 ker = tfk.MaternThreeHalves
#
# NameError: name 'misc' is not defined

# %%
spatial_factorization.sf.SpatialFactorization??

# %%
fit = spatial_factorization.sf.SpatialFactorization(J, L, Z, psd_kernel=ker, nonneg=True, lik="poi")
fit.init_loadings(D["Y"], X=Xtr, sz=D["sz"], shrinkage=0.3)
tro = training.ModelTrainer(fit)
# %time tro.train_model(*Dtf, status_freq=50) #about 3 mins
visualize.plot_loss(tro.loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fit = spatial_factorization.sf.SpatialFactorization(J, L, Z, psd_kernel=ker, nonneg=True, lik="poi")
#       2 fit.init_loadings(D["Y"], X=Xtr, sz=D["sz"], shrinkage=0.3)
#       3 tro = training.ModelTrainer(fit)
#
# NameError: name 'J' is not defined

# %%
help(spatial_factorization.ModelTrainer)
# Out:
# Help on class ModelTrainer in module spatial_factorization.training:
#
# class ModelTrainer(builtins.object)
#  |  ModelTrainer(model, lr=0.01, pickle_path=None, max_to_keep=3, **kwargs)
#  |
#  |  Time keeping policy:
#  |    * when object is first created, elapsed wtime and ptime are set to 0.0
#  |    * when train_model is called a wtic, ptic baseline is set
#  |    * whenever a checkpoint is saved or the object is pickled,
#  |    the elapsed time is added to wtime and ptime and a new tic baseline is set
#  |    * wtic and ptic are not stored, only the elapsed time is stored
#  |    * checkpointing and pickling require the user to specify the additional
#  |    elapsed time. If no time has elapsed the user can supply 0.0 values.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, lr=0.01, pickle_path=None, max_to_keep=3, **kwargs)
#  |      **kwargs are passed to tf.optimizers.[Optimizer] constructor
#  |
#  |  checkpoint(self, mgr, *args)
# ...

# %%
# Set the number of spatial factors you want to extract
n_factors = 10

# Create the NSF model by passing your AnnData object, number of factors,
# and specifying the key where spatial coordinates are stored (here assumed as 'spatial')
model = nsf.NSF(adata=adata_mer, n_factors=n_factors, spatial_key='spatial')

# Fit the model. You can adjust the number of epochs, learning rate, etc.
model.fit(epochs=1000, verbose=True)

# Once the model is fit, you can extract the factor matrices:
# e.g., spatial factors (patterns) and gene loadings.
factors = model.get_factors()    # spatial patterns
loadings = model.get_loadings()  # gene contributions to each factor
