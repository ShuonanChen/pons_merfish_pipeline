# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import json
import cv2
import os,glob
import re
import configurations
from func.registerCCF_util import *
# After:
from configurations import IMAGE_DIR
imagedir = IMAGE_DIR

# %%
imagedir
# Out:
# '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/'

# %%
glob.glob(imagedir+'/*')
# Out:
# ['/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/image_xml',
#  '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/visualign_rez',
#  '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/filt_neurons',
#  '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/foo.html',
#  '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/results',
#  '/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain/register_CCF_cleaned_NEW.ipynb']

# %% [markdown]
# # set up the target image you are loading

# %%
scaling_factor=1/32;
name_of_slice = 'MouseC_C2'
image_files=glob.glob(imagedir+f'/image_xml/*{name_of_slice}.jpg')
print(image_files)
slicenum = [1] # I only had 1 image so just one!!!!
# Out:
# ['/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain//image_xml/cell_img_MouseC_C2.jpg']

# %%
image_files
# Out:
# ['/Users/shuonan.chen/Documents/project/merfish_register/go_register_w_QuickNiii/2025more_brain//image_xml/cell_img_MouseC_C2.jpg']

# %%
im = cv2.imread(image_files[0])
w=im.shape[1]
h=im.shape[0]

json_name=image_files 
d = {'slicenum': slicenum, 'json_name': json_name}#'flat_name':flat_name}
name_df=pd.DataFrame(data=d)

# %%
name_df
# Out:
#    slicenum                                          json_name
# 0         1  /Users/shuonan.chen/Documents/project/merfish_...

# %% [markdown]
# # load and apply scaling factor

# %%
neurons=pd.read_csv(imagedir+f'/filt_neurons/filt_neurons_{name_of_slice}.csv')
# neurons=pd.read_csv(imagedir+f'/filt_neurons_all/filt_neurons_{name_of_slice}.csv')
neurons=neurons[neurons['slice'].astype(int).isin(slicenum)]
Max=neurons['x'].max()
Min=neurons['y'].max()
neurons['rescale_x']=(neurons['x']*scaling_factor)
neurons['rescale_y']=(neurons['y']*scaling_factor)

# %%
neurons
# Out:
#                                       neuron_id             x             y  \
# 0       100001939703600614937490375160630714002  55201.256822  44225.139536
# 1       100005672364209565697593395174744074251  33583.920237  53293.555207
# 2       100006540040464446802363639656821191787  58599.525456  31515.630003
# 3        10000877333642728125143865913104806455  59343.792174  46416.780037
# 4       100010536394310114317746001224064732083  15742.340264  36130.566686
# ...                                         ...           ...           ...
# 218619   99997227962950670925213033216216216434  31984.008128  23359.986926
# 218620   99999029411501813388788101446677696617   6878.921010  28226.048332
# 218621   99999318695664613361624204675170087911  21150.121838  52329.040804
# 218622   99999570753591041020110440922320024110  19512.520865   2792.545428
# 218623   99999917322142890131253455691043715433  35217.512598  43933.295422
#
#         slice  subclass  clustid    rescale_x    rescale_y
# 0           1         0        0  1725.039276  1382.035610
# 1           1        16       16  1049.497507  1665.423600
# 2           1        21       21  1831.235171   984.863438
# 3           1         6        6  1854.493505  1450.524376
# 4           1         2        2   491.948133  1129.080209
# ...       ...       ...      ...          ...          ...
# 218619      1        21       21   999.500254   729.999591
# 218620      1        36       36   214.966282   882.064010
# 218621      1        65       65   660.941307  1635.282525
# 218622      1        65       65   609.766277    87.267045
# 218623      1        18       18  1100.547269  1372.915482
#
# [218624 rows x 8 columns]

# %% [markdown]
# # invert visualign

# %%
with open(imagedir+f"/visualign_rez/{name_of_slice}.json") as f:
    vafile=json.load(f)
details={s.get('filename'):s for s in vafile['slices']}
assert(name_of_slice in list(details.keys())[0])

# %%
s = details.get(image_files[0])

# %%
details.get('width')

# %%
details.keys()
# Out:
# dict_keys(['cell_img_MouseC_C2.jpg'])

# %%
rez = neurons.groupby('slice', group_keys=False).apply(lambda g: get_adjusted_points(g.assign(slice=g.name), name_df,details)).reset_index(drop=True)
neurons[['adjusted_x', 'adjusted_y']]= rez


neurons_nl=neurons.copy()
neurons_nl['clustid'] =neurons_nl['clustid'].astype(str)

# %% [markdown]
# # invert quickniiii

# %%
def get_record(s):
    return {
        'filename':s.get('filename'),
        'height': s.get('height'),
        'width': s.get('width'), 
        'ox': s.get('anchoring')[0], 
        'oy': s.get('anchoring')[1],
        'oz': s.get('anchoring')[2],
        'ux': s.get('anchoring')[3],
        'uy': s.get('anchoring')[4],
        'uz': s.get('anchoring')[5], 
        'vx': s.get('anchoring')[6], 
        'vy': s.get('anchoring')[7],
        'vz': s.get('anchoring')[8],
    }

# %%
f = open(imagedir + f'/image_xml/quicknii_{name_of_slice}.json','r')
data=json.loads(f.read())
anchor=pd.DataFrame.from_records([get_record(s) for s in data['slices']])
f.close()

vox_dfs = []
for slice_num, df in neurons_nl.groupby('slice'):
    quicknii_cord = get_quicknii_cord(slice_num, df,name_df,anchor,h,w) # Height and Width of image file
    vox_cord = get_vox_cord(quicknii_cord)
    vox_dfs += [vox_cord]    
vox_df = pd.concat(vox_dfs)

# %% [markdown]
# # plot the results

# %%
plot_df = vox_df.copy()
fig = px.scatter_3d(plot_df, x='y_CCF', y='z_CCF', z='x_CCF', color='clustid')
fig.update_traces(marker=dict(size=.5),
                  selector=dict(mode='markers'))
fig.update_scenes(aspectmode='data')
fig.show()

# %% [markdown]
# # save

# %% [raw]
# vox_df.to_csv(image_dir+f'/results/registered_{name_of_slice}.csv',index=False)

# %%
print(f'done for {name_of_slice}')
